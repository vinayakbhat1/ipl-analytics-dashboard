# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# 🔹 Encode password (IMPORTANT because of #)
password = quote_plus("#Vinu112233")

# 🔹 Create connection
engine = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/ipl")
# 🔹 File paths (use raw string r"")
files = {
    "players_salary": r"F:\CODING\ipl project\clean data\all_players_salary_final.csv",
    "matches": r"F:\CODING\ipl project\clean data\matches_clean.csv",
    "ball_by_ball": r"F:\CODING\ipl project\clean data\ball_by_ball_clean.csv",
    "team_summary": r"F:\CODING\ipl project\clean data\ipl_auction_team_summary.csv"
}

# 🔹 Loop and upload
for table_name, file_path in files.items():
    try:
        df = pd.read_csv(file_path)

        df.to_sql(
            name=table_name,
            con=engine,
            if_exists='replace',
            index=False
        )

        print(f"{table_name} uploaded successfully")

    except Exception as e:
        print(f"Error in {table_name}: {e}")
# Out:
# players_salary uploaded successfully
# matches uploaded successfully
# ball_by_ball uploaded successfully
# team_summary uploaded successfully

# %%
pip install pymysql sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("#Vinu112233")

engine = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/ipl_db")

with engine.connect() as conn:
    print("Connected successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...
